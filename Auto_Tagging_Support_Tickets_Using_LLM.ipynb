# %% [markdown]
# <a href="https://colab.research.google.com/github/fehmidataj27-dotcom/2nd-Task-/blob/main/Auto_Tagging_Support_Tickets_Using_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch pandas

# %%
import pandas as pd
from transformers import pipeline

# %%
data = {
    "ticket": [
        "My internet connection is very slow",
        "I forgot my account password",
        "The payment page is not loading",
        "My order has not arrived yet",
        "The mobile app keeps crashing"
    ]
}

df = pd.DataFrame(data)

df.head()
# Out:
#                                 ticket
# 0  My internet connection is very slow
# 1         I forgot my account password
# 2      The payment page is not loading
# 3         My order has not arrived yet
# 4        The mobile app keeps crashing

# %%
labels = [
    "technical issue",
    "billing problem",
    "account issue",
    "delivery issue",
    "general inquiry"
]

# %%
classifier = pipeline(
    "zero-shot-classification",
    model="facebook/bart-large-mnli"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ...

# %%
results = []

for ticket in df["ticket"]:

    prediction = classifier(ticket, labels)

    top3 = prediction["labels"][:3]

    results.append(top3)

df["top_3_tags"] = results

df
# Out:
#                                 ticket  \
# 0  My internet connection is very slow
# 1         I forgot my account password
# 2      The payment page is not loading
# 3         My order has not arrived yet
# 4        The mobile app keeps crashing
#
#                                           top_3_tags
# 0  [technical issue, account issue, general inquiry]
# 1  [account issue, technical issue, general inquiry]
# 2  [billing problem, technical issue, account issue]
# 3   [delivery issue, account issue, technical issue]
# 4  [technical issue, account issue, general inquiry]

# %%
for i in range(len(df)):
    print("Ticket:", df["ticket"][i])
    print("Predicted Tags:", df["top_3_tags"][i])
    print()
# Out:
# Ticket: My internet connection is very slow
# Predicted Tags: ['technical issue', 'account issue', 'general inquiry']
#
# Ticket: I forgot my account password
# Predicted Tags: ['account issue', 'technical issue', 'general inquiry']
#
# Ticket: The payment page is not loading
# Predicted Tags: ['billing problem', 'technical issue', 'account issue']
#
# Ticket: My order has not arrived yet
# Predicted Tags: ['delivery issue', 'account issue', 'technical issue']
#
# Ticket: The mobile app keeps crashing
# Predicted Tags: ['technical issue', 'account issue', 'general inquiry']

# %%
df.to_csv("tagged_tickets.csv", index=False)
